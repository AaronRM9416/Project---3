# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pymysql
pymysql.install_as_MySQLdb()

# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %%
# Open saved file and preview again
basicsdf = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basicsdf.head()
basicsdf
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# 3      tt0088751     movie                                  The Naked Monster
# 4      tt0096056     movie                               Crime and Punishment
# ...          ...       ...                                                ...
# 82907  tt9914942     movie                             Life Without Sara Amat
# 82908  tt9915872     movie                               The Last White Witch
# 82909  tt9916170     movie                                      The Rehearsal
# 82910  tt9916190     movie                                          Safeguard
# 82911  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0     2001.0      NaN
# 1      El Tango del Viudo y Su Espejo Deformante        0     2020.0      NaN
# 2                     The Other Side of the Wind        0     2018.0      NaN
# 3                              The Naked Monster        0     2005.0      NaN
# 4                           Crime and Punishment        0     2002.0      NaN
# ...                                          ...      ...        ...      ...
# 82907                 La vida sense la Sara Amat        0     2019.0      NaN
# 82908                  My Girlfriend is a Wizard        0     2019.0      NaN
# 82909                                   O Ensaio        0     2019.0      NaN
# 82910                                  Safeguard        0     2020.0      NaN
# 82911                                   Akelarre        0     2020.0      NaN
#
#        runtimeMinutes                     genres
# 0                 118     Comedy,Fantasy,Romance
# 1                  70                      Drama
# 2                 122                      Drama
# 3                 100       Comedy,Horror,Sci-Fi
# 4                 126                      Drama
# ...               ...                        ...
# 82907              74                      Drama
# 82908              97       Comedy,Drama,Fantasy
# 82909              51                      Drama
# 82910              95  Action,Adventure,Thriller
# 82911              92              Drama,History
#
# [82912 rows x 9 columns]

# %%
basicsdf['genres_split'] = basicsdf['genres'].str.split(',')
basicsdf
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# 3      tt0088751     movie                                  The Naked Monster
# 4      tt0096056     movie                               Crime and Punishment
# ...          ...       ...                                                ...
# 82907  tt9914942     movie                             Life Without Sara Amat
# 82908  tt9915872     movie                               The Last White Witch
# 82909  tt9916170     movie                                      The Rehearsal
# 82910  tt9916190     movie                                          Safeguard
# 82911  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0     2001.0      NaN
# 1      El Tango del Viudo y Su Espejo Deformante        0     2020.0      NaN
# 2                     The Other Side of the Wind        0     2018.0      NaN
# 3                              The Naked Monster        0     2005.0      NaN
# 4                           Crime and Punishment        0     2002.0      NaN
# ...                                          ...      ...        ...      ...
# 82907                 La vida sense la Sara Amat        0     2019.0      NaN
# 82908                  My Girlfriend is a Wizard        0     2019.0      NaN
# 82909                                   O Ensaio        0     2019.0      NaN
# 82910                                  Safeguard        0     2020.0      NaN
# 82911                                   Akelarre        0     2020.0      NaN
#
#        runtimeMinutes                     genres  \
# 0                 118     Comedy,Fantasy,Romance
# 1                  70                      Drama
# 2                 122                      Drama
# 3                 100       Comedy,Horror,Sci-Fi
# 4                 126                      Drama
# ...               ...                        ...
# 82907              74                      Drama
# 82908              97       Comedy,Drama,Fantasy
# 82909              51                      Drama
# 82910              95  Action,Adventure,Thriller
# 82911              92              Drama,History
#
#                         genres_split
# 0         [Comedy, Fantasy, Romance]
# 1                            [Drama]
# 2                            [Drama]
# 3           [Comedy, Horror, Sci-Fi]
# 4                            [Drama]
# ...                              ...
# 82907                        [Drama]
# 82908       [Comedy, Drama, Fantasy]
# 82909                        [Drama]
# 82910  [Action, Adventure, Thriller]
# 82911               [Drama, History]
#
# [82912 rows x 10 columns]

# %%
genres_split = basicsdf['genres'].str.split(",")

# explode the series and take the unique entries only
unique_genres = genres_split.explode().unique()
unique_genres
# Out:
# array(['Comedy', 'Fantasy', 'Romance', 'Drama', 'Horror', 'Sci-Fi',
#        'Mystery', 'Musical', 'Action', 'Adventure', 'Crime', 'Thriller',
#        'Music', 'Animation', 'Family', 'History', 'War', 'Biography',
#        'Sport', 'Western', 'Adult', 'Short', 'Reality-TV', 'News',
#        'Talk-Show', 'Game-Show'], dtype=object)

# %%
exploded_genres = basicsdf.explode('genres_split')
exploded_genres
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# ...          ...       ...                                                ...
# 82910  tt9916190     movie                                          Safeguard
# 82910  tt9916190     movie                                          Safeguard
# 82910  tt9916190     movie                                          Safeguard
# 82911  tt9916362     movie                                              Coven
# 82911  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0     2001.0      NaN
# 0                                 Kate & Leopold        0     2001.0      NaN
# 0                                 Kate & Leopold        0     2001.0      NaN
# 1      El Tango del Viudo y Su Espejo Deformante        0     2020.0      NaN
# 2                     The Other Side of the Wind        0     2018.0      NaN
# ...                                          ...      ...        ...      ...
# 82910                                  Safeguard        0     2020.0      NaN
# 82910                                  Safeguard        0     2020.0      NaN
# 82910                                  Safeguard        0     2020.0      NaN
# 82911                                   Akelarre        0     2020.0      NaN
# 82911                                   Akelarre        0     2020.0      NaN
#
#        runtimeMinutes                     genres genres_split
# 0                 118     Comedy,Fantasy,Romance       Comedy
# 0                 118     Comedy,Fantasy,Romance      Fantasy
# 0                 118     Comedy,Fantasy,Romance      Romance
# 1                  70                      Drama        Drama
# 2                 122                      Drama        Drama
# ...               ...                        ...          ...
# 82910              95  Action,Adventure,Thriller       Action
# 82910              95  Action,Adventure,Thriller    Adventure
# 82910              95  Action,Adventure,Thriller     Thriller
# 82911              92              Drama,History        Drama
# 82911              92              Drama,History      History
#
# [154935 rows x 10 columns]

# %%
unique_genres = sorted(exploded_genres['genres_split'].unique())

# %%
# saving just the tconst and genres as a new df
title_genres = exploded_genres[['tconst', 'genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0069049        Drama

# %%
# make a dictionary with list of unique genres as key and new integer id as values
genre_id_map = dict(zip(unique_genres, range(len(unique_genres))))
genre_id_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
genre_lookup = pd.DataFrame({'Genre_Name': genre_id_map.keys(),
                            'Genre_ID': genre_id_map.values()})

genre_lookup.head()
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
basics_sql = basics.copy()
basics_sql
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# 3      tt0088751     movie                                  The Naked Monster
# 4      tt0096056     movie                               Crime and Punishment
# ...          ...       ...                                                ...
# 82907  tt9914942     movie                             Life Without Sara Amat
# 82908  tt9915872     movie                               The Last White Witch
# 82909  tt9916170     movie                                      The Rehearsal
# 82910  tt9916190     movie                                          Safeguard
# 82911  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0     2001.0      NaN
# 1      El Tango del Viudo y Su Espejo Deformante        0     2020.0      NaN
# 2                     The Other Side of the Wind        0     2018.0      NaN
# 3                              The Naked Monster        0     2005.0      NaN
# 4                           Crime and Punishment        0     2002.0      NaN
# ...                                          ...      ...        ...      ...
# 82907                 La vida sense la Sara Amat        0     2019.0      NaN
# 82908                  My Girlfriend is a Wizard        0     2019.0      NaN
# 82909                                   O Ensaio        0     2019.0      NaN
# 82910                                  Safeguard        0     2020.0      NaN
# 82911                                   Akelarre        0     2020.0      NaN
#
#        runtimeMinutes                     genres  \
# 0                 118     Comedy,Fantasy,Romance
# 1                  70                      Drama
# 2                 122                      Drama
# 3                 100       Comedy,Horror,Sci-Fi
# 4                 126                      Drama
# ...               ...                        ...
# 82907              74                      Drama
# 82908              97       Comedy,Drama,Fantasy
# 82909              51                      Drama
# 82910              95  Action,Adventure,Thriller
# 82911              92              Drama,History
#
#                         genres_split
# 0         [Comedy, Fantasy, Romance]
# 1                            [Drama]
# 2                            [Drama]
# 3           [Comedy, Horror, Sci-Fi]
# 4                            [Drama]
# ...                              ...
# 82907                        [Drama]
# 82908       [Comedy, Drama, Fantasy]
# 82909                        [Drama]
# 82910  [Action, Adventure, Thriller]
# 82911               [Drama, History]
#
# [82912 rows x 10 columns]

# %%
basics_sql = basics_sql.drop(columns = ['originalTitle', 'isAdult', 'titleType', 'genres', 'genres_split'])

# %%
title_ratings = pd.read_csv('Data/title_ratings.csv.gz')
title_ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1917
# 1  tt0000002            5.8       260
# 2  tt0000005            6.2      2541
# 3  tt0000006            5.1       175
# 4  tt0000007            5.4       796

# %%
tmdb_data = pd.read_csv('Data/final_tmdb_data_2001.csv.gz')
tmdb_data.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /ab5yL8zgRotrICzGbEl10z24N71.jpg                   NaN
# 2  tt0114447    0.0                               NaN                   NaN
# 3  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
# 4  tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...      NaN
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 3  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
# 4   1000000.0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...      NaN
#
#          id original_language         original_title  ...     revenue  \
# 0       NaN               NaN                    NaN  ...         NaN
# 1   11232.0                en         Kate & Leopold  ...  76019048.0
# 2  151007.0                en       The Silent Force  ...         0.0
# 3   10696.0                en                Glitter  ...   5271666.0
# 4   17140.0                en  The Attic Expeditions  ...         0.0
#
#    runtime                                   spoken_languages    status  \
# 0      NaN                                                NaN       NaN
# 1    118.0  [{'english_name': 'Italian', 'iso_639_1': 'it'...  Released
# 2     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3    104.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline                  title  \
# 0                                                NaN                    NaN
# 1  If they lived in the same century they'd be pe...         Kate & Leopold
# 2  They left him for dead... They should have fin...       The Silent Force
# 3   In music she found her dream, her love, herself.                Glitter
# 4  His search for peace of mind... will leave his...  The Attic Expeditions
#
#    video  vote_average vote_count certification
# 0    NaN           NaN        NaN           NaN
# 1    0.0         6.322     1148.0         PG-13
# 2    0.0         5.000        3.0           NaN
# 3    0.0         4.600      118.0         PG-13
# 4    0.0         5.100       28.0             R
#
# [5 rows x 26 columns]

# %%
tmdb_data = tmdb_data[['imdb_id', 'revenue', 'budget', 'certification']]
tmdb_data.head()
# Out:
#      imdb_id     revenue      budget certification
# 0          0         NaN         NaN           NaN
# 1  tt0035423  76019048.0  48000000.0         PG-13
# 2  tt0114447         0.0         0.0           NaN
# 3  tt0118589   5271666.0  22000000.0         PG-13
# 4  tt0118652         0.0   1000000.0             R

# %%
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists

# %%
# Out:
# dict_keys(['api-key'])

# %%
connection_str = "mysql+pymysql://root:root@localhost/movies"

# %%
engine = create_engine(connection_str)

# %%
create_database(connection_str)

# %%
database_exists(connection_str)
# Out:
# True

# %%
basics_sql.to_sql('title_basics', engine, if_exists = 'replace')
# Out:
# 82912

# %%
title_ratings.to_sql('title_ratings', engine, if_exists = 'replace')
# Out:
# 471735

# %%
title_genres.to_sql('title_genres', engine, if_exists = 'replace')
# Out:
# 154935

# %%
genre_lookup.to_sql('genres', engine, if_exists = 'replace')
# Out:
# 26

# %%
tmdb_data.to_sql('tmdb_data', engine, if_exists = 'replace')

# %%
q = """SHOW TABLES;"""
pd.read_sql(q, engine)
# Out:
#   Tables_in_movies
# 0           genres
# 1     title_basics
# 2     title_genres
# 3    title_ratings

# %%
q = """SELECT *
from genres
limit 5;

"""
pd.read_sql(q, engine)
# Out:
#    index Genre_Name  Genre_ID
# 0      0     Action         0
# 1      1      Adult         1
# 2      2  Adventure         2
# 3      3  Animation         3
# 4      4  Biography         4

# %%
q = """SELECT *
from title_basics
limit 5;

"""
pd.read_sql(q, engine)
# Out:
#    index     tconst                                       primaryTitle  \
# 0      0  tt0035423                                     Kate & Leopold
# 1      1  tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2      2  tt0069049                         The Other Side of the Wind
# 3      3  tt0088751                                  The Naked Monster
# 4      4  tt0096056                               Crime and Punishment
#
#    startYear endYear  runtimeMinutes
# 0     2001.0    None             118
# 1     2020.0    None              70
# 2     2018.0    None             122
# 3     2005.0    None             100
# 4     2002.0    None             126

# %%
q = """SELECT *
from title_genres
limit 5;

"""
pd.read_sql(q, engine)
# Out:
#    index     tconst genres_split
# 0      0  tt0035423       Comedy
# 1      0  tt0035423      Fantasy
# 2      0  tt0035423      Romance
# 3      1  tt0062336        Drama
# 4      2  tt0069049        Drama

# %%
q = """SELECT *
from title_ratings
limit 5;

"""
pd.read_sql(q, engine)
# Out:
#    index     tconst  averageRating  numVotes
# 0      0  tt0000001            5.7      1917
# 1      1  tt0000002            5.8       260
# 2      2  tt0000005            6.2      2541
# 3      3  tt0000006            5.1       175
# 4      4  tt0000007            5.4       796

# %%
q = """SELECT *
from tmdb_data
limit 5;

"""
pd.read_sql(q, engine)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\pymysql\cursors.py:148, in Cursor.execute(self, query, args)
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\pymysql\cursors.py:310, in Cursor._query(self, q)
#     309 self._clear_result()
# --> 310 conn.query(q)
#     311 self._do_get_result()
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\pymysql\connections.py:548, in Connection.query(self, sql, unbuffered)
#     547 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549 return self._affected_rows
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\pymysql\connections.py:775, in Connection._read_query_result(self, unbuffered)
#     774     result = MySQLResult(self)
# --> 775     result.read()
#     776 self._result = result
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\pymysql\connections.py:1156, in MySQLResult.read(self)
#    1155 try:
# -> 1156     first_packet = self.connection._read_packet()
#    1158     if first_packet.is_ok_packet():
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\pymysql\connections.py:725, in Connection._read_packet(self, packet_type)
#     724         self._result.unbuffered_active = False
# --> 725     packet.raise_for_error()
#     726 return packet
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# ProgrammingError: (1146, "Table 'movies.tmdb_data' doesn't exist")
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In [45], line 6
#       1 q = """SELECT *
#       2 from tmdb_data
#       3 limit 5;
#       4
#       5 """
# ----> 6 pd.read_sql(q, engine)
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\sql.py:592, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     583     return pandas_sql.read_table(
#     584         sql,
#     585         index_col=index_col,
#    (...)
#     589         chunksize=chunksize,
#     590     )
#     591 else:
# --> 592     return pandas_sql.read_query(
#     593         sql,
#     594         index_col=index_col,
#     595         params=params,
#     596         coerce_float=coerce_float,
#     597         parse_dates=parse_dates,
#     598         chunksize=chunksize,
#     599     )
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\sql.py:1557, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1509 """
#    1510 Read SQL query into a DataFrame.
#    1511
#    (...)
#    1553
#    1554 """
#    1555 args = _convert_params(sql, params)
# -> 1557 result = self.execute(*args)
#    1558 columns = result.keys()
#    1560 if chunksize is not None:
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\sql.py:1402, in SQLDatabase.execute(self, *args, **kwargs)
#    1400 def execute(self, *args, **kwargs):
#    1401     """Simple passthrough to SQLAlchemy connectable"""
# -> 1402     return self.connectable.execution_options().execute(*args, **kwargs)
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\util\deprecations.py:401, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     399 if not skip_warning:
#     400     _warn_with_version(message, version, wtype, stacklevel=3)
# --> 401 return fn(*args, **kwargs)
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\engine\base.py:3176, in Engine.execute(self, statement, *multiparams, **params)
#    3158 """Executes the given construct and returns a
#    3159 :class:`_engine.CursorResult`.
#    3160
#    (...)
#    3173
#    3174 """
#    3175 connection = self.connect(close_with_result=True)
# -> 3176 return connection.execute(statement, *multiparams, **params)
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\engine\base.py:1291, in Connection.execute(self, statement, *multiparams, **params)
#    1282 if isinstance(statement, util.string_types):
#    1283     util.warn_deprecated_20(
#    1284         "Passing a string to Connection.execute() is "
#    1285         "deprecated and will be removed in version 2.0.  Use the "
#    (...)
#    1288         "driver-level SQL string."
#    1289     )
# -> 1291     return self._exec_driver_sql(
#    1292         statement,
#    1293         multiparams,
#    1294         params,
#    1295         _EMPTY_EXECUTION_OPTS,
#    1296         future=False,
#    1297     )
#    1299 try:
#    1300     meth = statement._execute_on_connection
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\engine\base.py:1595, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1585         (
#    1586             statement,
#    1587             distilled_params,
#    (...)
#    1591             statement, distilled_parameters, execution_options
#    1592         )
#    1594 dialect = self.dialect
# -> 1595 ret = self._execute_context(
#    1596     dialect,
#    1597     dialect.execution_ctx_cls._init_statement,
#    1598     statement,
#    1599     distilled_parameters,
#    1600     execution_options,
#    1601     statement,
#    1602     distilled_parameters,
#    1603 )
#    1605 if not future:
#    1606     if self._has_events or self.engine._has_events:
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\engine\base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1859             branched.close()
#    1861 except BaseException as e:
# -> 1862     self._handle_dbapi_exception(
#    1863         e, statement, parameters, cursor, context
#    1864     )
#    1866 return result
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\engine\base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042 elif should_wrap:
# -> 2043     util.raise_(
#    2044         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045     )
#    2046 else:
#    2047     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\util\compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1817                 break
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#    1824     self.dispatch.after_cursor_execute(
#    1825         self,
#    1826         cursor,
#    (...)
#    1830         context.executemany,
#    1831     )
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\pymysql\cursors.py:148, in Cursor.execute(self, query, args)
#     144     pass
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#     150 return result
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\pymysql\cursors.py:310, in Cursor._query(self, q)
#     308 self._last_executed = q
#     309 self._clear_result()
# --> 310 conn.query(q)
#     311 self._do_get_result()
#     312 return self.rowcount
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\pymysql\connections.py:548, in Connection.query(self, sql, unbuffered)
#     546     sql = sql.encode(self.encoding, "surrogateescape")
#     547 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549 return self._affected_rows
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\pymysql\connections.py:775, in Connection._read_query_result(self, unbuffered)
#     773 else:
#     774     result = MySQLResult(self)
# --> 775     result.read()
#     776 self._result = result
#     777 if result.server_status is not None:
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\pymysql\connections.py:1156, in MySQLResult.read(self)
#    1154 def read(self):
#    1155     try:
# -> 1156         first_packet = self.connection._read_packet()
#    1158         if first_packet.is_ok_packet():
#    1159             self._read_ok_packet(first_packet)
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\pymysql\connections.py:725, in Connection._read_packet(self, packet_type)
#     723     if self._result is not None and self._result.unbuffered_active is True:
#     724         self._result.unbuffered_active = False
# --> 725     packet.raise_for_error()
#     726 return packet
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File c:\Users\Aaron\anaconda3\envs\dojo-env\lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# ProgrammingError: (pymysql.err.ProgrammingError) (1146, "Table 'movies.tmdb_data' doesn't exist")
# [SQL: SELECT *
# from tmdb_data
# limit 5;
#
# ]
# (Background on this error at: https://sqlalche.me/e/14/f405)
